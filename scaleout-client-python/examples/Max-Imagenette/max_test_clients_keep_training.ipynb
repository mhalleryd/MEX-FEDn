# %%
from client.model import compile_model, save_parameters
from client.data import load_data
from server_functions import ServerFunctions
from scaleout.client.edge_client import EdgeClient
import torch
import matplotlib.pyplot as plt
import numpy as np
import client
import client.startup
import importlib

importlib.reload(client.startup)
importlib.reload(client)


model = compile_model()
print(model)

N_clients = 2
edge = EdgeClient()
clients = [client.startup.MyClient(edge) for _ in range(N_clients)]
# Out:
# Net(
#   (fc1): Linear(in_features=784, out_features=64, bias=True)
#   (fc2): Linear(in_features=64, out_features=32, bias=True)
#   (fc3): Linear(in_features=32, out_features=10, bias=True)
# )

# %%
import pickle
import torchvision
from torchvision import transforms, datasets
def niid_loader(data_path=None, dataset_name='mnist', is_train=True, download=False):
    """Implements non-iid data across clients using NIID-bench: 
    https://github.com/Xtra-Computing/NIID-Bench#"""

    
    if data_path == None:
        print('No data path given!')
        return
        
    
    #Imagenette för convnext
    if dataset_name == 'imagenette':
        data = load_data(data_path=data_path, is_train=is_train, download=download)
        print(data)
        print(data[0][0].shape)

        #non-iid map
        with open('./max_dataidx_maps/imagenette_500samples_dataidx_map_labeldir_beta05.pkl', 'rb') as f:
            idx_dict = pickle.load(f)


        with open('./max_dataidx_maps/imagenette_indices.pkl', 'rb') as f:
            indices_map = pickle.load(f)    #Mappar subset-idx till riktiga idx i datasetet


        client_ds = [
            torch.utils.data.Subset(data, indices_map[indices])
            for key, indices in idx_dict.items()
            ]
        
            
    #MNIST
    elif dataset_name == 'mnist':
        data = datasets.MNIST(
            root=data_path, 
            train=is_train,
            download=download,
            transform=transforms.Compose([
                transforms.ToTensor()
            ])
        )

        #non-iid map
        with open('./max_dataidx_maps/net_dataidx_map_labeldir_beta05.pkl', 'rb') as f:
            idx_dict = pickle.load(f)

        client_ds = [
            torch.utils.data.Subset(data, indices)
            for key, indices in idx_dict.items()
            ]
   

    return client_ds

# #IID
# data = datasets.MNIST(
#             root='./max_data', 
#             train=True,
#             download=False,
#             transform=transforms.Compose([
#                 transforms.ToTensor()
#             ])
#         )
# client_ds = torch.utils.data.random_split(data, [0.5, 0.5])


client_ds = niid_loader(
    data_path='./max_data', 
    is_train=True, 
    dataset_name='mnist',
    )


print('klar inläsning')
labels = [[] for _ in range(N_clients)]
for c in range(N_clients):
    for _, label in client_ds[c]:
        labels[c].append(label)

#Client data distribution
fig, axs = plt.subplots(1,N_clients, figsize=(12,4))
for i, client_labels in enumerate(labels):
    axs[i].hist(client_labels, bins=np.arange(11)-0.5)
    axs[i].set_title(f'Client {i} data label distribution (total: {len(client_labels)})')
    axs[i].set_xlabel('Class')
    axs[i].set_xticks(np.arange(10))
plt.show()
# Out:
# klar inläsning

# %%
from torch.utils.data import DataLoader, TensorDataset

def dataset_to_tensor(dataset, batch_size=256, num_workers=0):
    loader = DataLoader(dataset,
                        batch_size=batch_size,
                        shuffle=False,
                        num_workers=num_workers)

    xs = []
    ys = []

    for x, y in loader:
        xs.append(x)
        ys.append(y)

    X = torch.cat(xs)
    Y = torch.cat(ys)

    return TensorDataset(X, Y)

# %%
from copy import deepcopy
from scaleoututil.serverfunctions.serverfunctionsbase import RoundType
from scaleoututil.utils.model import ScaleoutModel
from collections import defaultdict


clients = [client.startup.MyClient(edge) for _ in range(N_clients)]
#initialize global params
global_params = save_parameters(model)

client_ids = [i for i in range(N_clients)]
server_functions = ServerFunctions()

ram_datasets = [dataset_to_tensor(ds, batch_size=32) for ds in client_ds]
#Dataloaders
client_dl = [torch.utils.data.DataLoader(
    dataset=ds,
    batch_size=32,
    ) 
    for ds in ram_datasets
    ]

metrics_list = defaultdict(lambda: defaultdict(list))

own_params = dict({id: global_params for id in client_ids})
#for .. (this is one FL round)
for round in range(10):
    selected = server_functions.client_selection(client_ids, RoundType.TRAINING, clients, 0.98) 
    settings = server_functions.client_settings(global_params) #Transform to list

    params_list = dict()
    losses = []
    for id in client_ids:
        #Olika datapartitioner på olika clients
        params, metadata, metrics = clients[id].train(
            scaleout_model=own_params[id], #global_params, 
            settings=settings,
            data_loader = client_dl[id]
            )
        if id in selected:
            params_list[id] =(params.get_model_params(), metadata)
        else:
            own_params[id] = params
        
        for key, value in metrics.items():
            metrics_list[id][key].append(value)

        # metrics_list[id]['training_loss'].append(metrics['training_loss'])
        # metrics_list[id]['training_accuracy'].append(metrics['training_accuracy'])
        # metrics_list[id]['norm'].append(metrics['norm'])
    
    #Aggregate
    if len(selected) > 0:
        new_params = server_functions.aggregate(global_params.get_model_params(), params_list)
        global_params = global_params.from_model_params(new_params)
        for id in selected:
            own_params[id] = global_params
# Out:
# Client 0 has drift None
# Client 1 has drift None
# Epoch 0/0 | Batch 0/914 | Loss: 2.2896
# Epoch 0/0 | Batch 100/914 | Loss: 2.1104
# Epoch 0/0 | Batch 200/914 | Loss: 1.8357
# Epoch 0/0 | Batch 300/914 | Loss: 1.8421
# Epoch 0/0 | Batch 400/914 | Loss: 1.4302
# Epoch 0/0 | Batch 500/914 | Loss: 1.4513
# Epoch 0/0 | Batch 600/914 | Loss: 1.0940
# Epoch 0/0 | Batch 700/914 | Loss: 1.3019
# Epoch 0/0 | Batch 800/914 | Loss: 0.8890
# Epoch 0/0 | Batch 900/914 | Loss: 0.7638
# 2026-02-17 09:32:02 [ERROR] Missing context for logging metric.
# Epoch 0 finished | Loss: 1.4871 | Acc: 0.4945
# Epoch 0/0 | Batch 0/960 | Loss: 2.3553
# Epoch 0/0 | Batch 100/960 | Loss: 2.1727
# Epoch 0/0 | Batch 200/960 | Loss: 1.8684
# Epoch 0/0 | Batch 300/960 | Loss: 1.9074
# Epoch 0/0 | Batch 400/960 | Loss: 1.6382
# Epoch 0/0 | Batch 500/960 | Loss: 1.2709
# Epoch 0/0 | Batch 600/960 | Loss: 1.0911
# Epoch 0/0 | Batch 700/960 | Loss: 1.1020
# Epoch 0/0 | Batch 800/960 | Loss: 0.9595
# Epoch 0/0 | Batch 900/960 | Loss: 0.8764
# 2026-02-17 09:32:07 [ERROR] Missing context for logging metric.
# Epoch 0 finished | Loss: 1.4040 | Acc: 0.5151
# Models aggregated
# Client 0 has drift 0.9082359075546265
# Client 1 has drift 0.8948731422424316
# Epoch 0/0 | Batch 0/914 | Loss: 1.9139
# Epoch 0/0 | Batch 100/914 | Loss: 1.1317
# Epoch 0/0 | Batch 200/914 | Loss: 0.7796
# Epoch 0/0 | Batch 300/914 | Loss: 0.6516
# Epoch 0/0 | Batch 400/914 | Loss: 0.5826
# Epoch 0/0 | Batch 500/914 | Loss: 0.7981
# Epoch 0/0 | Batch 600/914 | Loss: 0.4638
# Epoch 0/0 | Batch 700/914 | Loss: 0.5750
# Epoch 0/0 | Batch 800/914 | Loss: 0.6762
# Epoch 0/0 | Batch 900/914 | Loss: 0.4121
# 2026-02-17 09:32:12 [ERROR] Missing context for logging metric.
# Epoch 0 finished | Loss: 0.7272 | Acc: 0.7827
# Epoch 0/0 | Batch 0/960 | Loss: 1.6486
# Epoch 0/0 | Batch 100/960 | Loss: 0.7979
# Epoch 0/0 | Batch 200/960 | Loss: 0.7534
# Epoch 0/0 | Batch 300/960 | Loss: 0.8357
# Epoch 0/0 | Batch 400/960 | Loss: 0.7940
# Epoch 0/0 | Batch 500/960 | Loss: 0.5954
# Epoch 0/0 | Batch 600/960 | Loss: 0.5771
# Epoch 0/0 | Batch 700/960 | Loss: 0.4693
# Epoch 0/0 | Batch 800/960 | Loss: 0.4853
# Epoch 0/0 | Batch 900/960 | Loss: 0.5006
# 2026-02-17 09:32:17 [ERROR] Missing context for logging metric.
# Epoch 0 finished | Loss: 0.6606 | Acc: 0.8042
# Models aggregated
# Client 0 has drift 0.9579951167106628
# Client 1 has drift 0.9574885368347168
# Epoch 0/0 | Batch 0/914 | Loss: 1.5728
# Epoch 0/0 | Batch 100/914 | Loss: 0.7380
# Epoch 0/0 | Batch 200/914 | Loss: 0.5517
# Epoch 0/0 | Batch 300/914 | Loss: 0.5183
# Epoch 0/0 | Batch 400/914 | Loss: 0.4231
# Epoch 0/0 | Batch 500/914 | Loss: 0.6026
# Epoch 0/0 | Batch 600/914 | Loss: 0.4041
# Epoch 0/0 | Batch 700/914 | Loss: 0.4362
# Epoch 0/0 | Batch 800/914 | Loss: 0.4114
# Epoch 0/0 | Batch 900/914 | Loss: 0.2714
# 2026-02-17 09:32:21 [ERROR] Missing context for logging metric.
# Epoch 0 finished | Loss: 0.5167 | Acc: 0.8456
# Epoch 0/0 | Batch 0/960 | Loss: 1.0700
# Epoch 0/0 | Batch 100/960 | Loss: 0.5920
# Epoch 0/0 | Batch 200/960 | Loss: 0.4245
# Epoch 0/0 | Batch 300/960 | Loss: 0.6921
# Epoch 0/0 | Batch 400/960 | Loss: 0.5977
# Epoch 0/0 | Batch 500/960 | Loss: 0.3574
# Epoch 0/0 | Batch 600/960 | Loss: 0.3209
# Epoch 0/0 | Batch 700/960 | Loss: 0.3832
# Epoch 0/0 | Batch 800/960 | Loss: 0.2206
# Epoch 0/0 | Batch 900/960 | Loss: 0.4570
# 2026-02-17 09:32:26 [ERROR] Missing context for logging metric.
# Epoch 0 finished | Loss: 0.4621 | Acc: 0.8593
# Models aggregated
# Client 0 has drift 0.984447717666626
# Client 1 has drift 0.9843576550483704
# Epoch 0/0 | Batch 0/914 | Loss: 1.0743
# Epoch 0/0 | Batch 100/914 | Loss: 0.3611
# Epoch 0/0 | Batch 200/914 | Loss: 0.4520
# Epoch 0/0 | Batch 300/914 | Loss: 0.5801
# Epoch 0/0 | Batch 400/914 | Loss: 0.2978
# Epoch 0/0 | Batch 500/914 | Loss: 0.4441
# Epoch 0/0 | Batch 600/914 | Loss: 0.3334
# Epoch 0/0 | Batch 700/914 | Loss: 0.4199
# Epoch 0/0 | Batch 800/914 | Loss: 0.3430
# Epoch 0/0 | Batch 900/914 | Loss: 0.1845
# 2026-02-17 09:32:31 [ERROR] Missing context for logging metric.
# Epoch 0 finished | Loss: 0.4349 | Acc: 0.8700
# Epoch 0/0 | Batch 0/960 | Loss: 0.7251
# Epoch 0/0 | Batch 100/960 | Loss: 0.4845
# Epoch 0/0 | Batch 200/960 | Loss: 0.3423
# Epoch 0/0 | Batch 300/960 | Loss: 0.7384
# Epoch 0/0 | Batch 400/960 | Loss: 0.3934
# Epoch 0/0 | Batch 500/960 | Loss: 0.2356
# Epoch 0/0 | Batch 600/960 | Loss: 0.3513
# Epoch 0/0 | Batch 700/960 | Loss: 0.2322
# Epoch 0/0 | Batch 800/960 | Loss: 0.1958
# Epoch 0/0 | Batch 900/960 | Loss: 0.2278
# 2026-02-17 09:32:35 [ERROR] Missing context for logging metric.
# Epoch 0 finished | Loss: 0.3869 | Acc: 0.8845
# Client 0 has drift 0.9913057684898376
# Client 1 has drift 0.991233229637146
# Epoch 0/0 | Batch 0/914 | Loss: 0.3660
# Epoch 0/0 | Batch 100/914 | Loss: 0.4508
# Epoch 0/0 | Batch 200/914 | Loss: 0.4319
# Epoch 0/0 | Batch 300/914 | Loss: 0.2344
# Epoch 0/0 | Batch 400/914 | Loss: 0.2434
# Epoch 0/0 | Batch 500/914 | Loss: 0.2139
# Epoch 0/0 | Batch 600/914 | Loss: 0.3079
# Epoch 0/0 | Batch 700/914 | Loss: 0.4368
# Epoch 0/0 | Batch 800/914 | Loss: 0.3664
# Epoch 0/0 | Batch 900/914 | Loss: 0.2238
# 2026-02-17 09:32:40 [ERROR] Missing context for logging metric.
# Epoch 0 finished | Loss: 0.3533 | Acc: 0.8941
# Epoch 0/0 | Batch 0/960 | Loss: 0.3752
# Epoch 0/0 | Batch 100/960 | Loss: 0.3665
# Epoch 0/0 | Batch 200/960 | Loss: 0.3189
# Epoch 0/0 | Batch 300/960 | Loss: 0.5547
# Epoch 0/0 | Batch 400/960 | Loss: 0.2863
# Epoch 0/0 | Batch 500/960 | Loss: 0.2373
# Epoch 0/0 | Batch 600/960 | Loss: 0.2330
# Epoch 0/0 | Batch 700/960 | Loss: 0.1848
# Epoch 0/0 | Batch 800/960 | Loss: 0.1182
# Epoch 0/0 | Batch 900/960 | Loss: 0.2817
# 2026-02-17 09:32:45 [ERROR] Missing context for logging metric.
# Epoch 0 finished | Loss: 0.3085 | Acc: 0.9072
# Client 0 has drift 0.99750816822052
# Client 1 has drift 0.9973403215408325
# Epoch 0/0 | Batch 0/914 | Loss: 0.3556
# Epoch 0/0 | Batch 100/914 | Loss: 0.3842
# Epoch 0/0 | Batch 200/914 | Loss: 0.4040
# Epoch 0/0 | Batch 300/914 | Loss: 0.2434
# Epoch 0/0 | Batch 400/914 | Loss: 0.2216
# Epoch 0/0 | Batch 500/914 | Loss: 0.4053
# Epoch 0/0 | Batch 600/914 | Loss: 0.2778
# Epoch 0/0 | Batch 700/914 | Loss: 0.3228
# Epoch 0/0 | Batch 800/914 | Loss: 0.3325
# Epoch 0/0 | Batch 900/914 | Loss: 0.2299
# 2026-02-17 09:32:50 [ERROR] Missing context for logging metric.
# Epoch 0 finished | Loss: 0.3142 | Acc: 0.9066
# Epoch 0/0 | Batch 0/960 | Loss: 0.3147
# Epoch 0/0 | Batch 100/960 | Loss: 0.5085
# Epoch 0/0 | Batch 200/960 | Loss: 0.1790
# Epoch 0/0 | Batch 300/960 | Loss: 0.4261
# Epoch 0/0 | Batch 400/960 | Loss: 0.2241
# Epoch 0/0 | Batch 500/960 | Loss: 0.1910
# Epoch 0/0 | Batch 600/960 | Loss: 0.3122
# Epoch 0/0 | Batch 700/960 | Loss: 0.2515
# Epoch 0/0 | Batch 800/960 | Loss: 0.2413
# Epoch 0/0 | Batch 900/960 | Loss: 0.2737
# 2026-02-17 09:32:55 [ERROR] Missing context for logging metric.
# Epoch 0 finished | Loss: 0.2712 | Acc: 0.9193
# Client 0 has drift 0.9983365535736084
# Client 1 has drift 0.9982519149780273
# Epoch 0/0 | Batch 0/914 | Loss: 0.3155
# Epoch 0/0 | Batch 100/914 | Loss: 0.1759
# Epoch 0/0 | Batch 200/914 | Loss: 0.3285
# Epoch 0/0 | Batch 300/914 | Loss: 0.2571
# Epoch 0/0 | Batch 400/914 | Loss: 0.1597
# Epoch 0/0 | Batch 500/914 | Loss: 0.2007
# Epoch 0/0 | Batch 600/914 | Loss: 0.2961
# Epoch 0/0 | Batch 700/914 | Loss: 0.2305
# Epoch 0/0 | Batch 800/914 | Loss: 0.2590
# Epoch 0/0 | Batch 900/914 | Loss: 0.1451
# 2026-02-17 09:33:00 [ERROR] Missing context for logging metric.
# Epoch 0 finished | Loss: 0.2908 | Acc: 0.9151
# Epoch 0/0 | Batch 0/960 | Loss: 0.3333
# Epoch 0/0 | Batch 100/960 | Loss: 0.3792
# Epoch 0/0 | Batch 200/960 | Loss: 0.1568
# Epoch 0/0 | Batch 300/960 | Loss: 0.5484
# Epoch 0/0 | Batch 400/960 | Loss: 0.2898
# Epoch 0/0 | Batch 500/960 | Loss: 0.1446
# Epoch 0/0 | Batch 600/960 | Loss: 0.3030
# Epoch 0/0 | Batch 700/960 | Loss: 0.1281
# Epoch 0/0 | Batch 800/960 | Loss: 0.1188
# Epoch 0/0 | Batch 900/960 | Loss: 0.2640
# 2026-02-17 09:33:05 [ERROR] Missing context for logging metric.
# Epoch 0 finished | Loss: 0.2533 | Acc: 0.9240
# Client 0 has drift 0.9987499117851257
# Client 1 has drift 0.9985911846160889
# Epoch 0/0 | Batch 0/914 | Loss: 0.2602
# Epoch 0/0 | Batch 100/914 | Loss: 0.1533
# Epoch 0/0 | Batch 200/914 | Loss: 0.3993
# Epoch 0/0 | Batch 300/914 | Loss: 0.2417
# Epoch 0/0 | Batch 400/914 | Loss: 0.1201
# Epoch 0/0 | Batch 500/914 | Loss: 0.1713
# Epoch 0/0 | Batch 600/914 | Loss: 0.3924
# Epoch 0/0 | Batch 700/914 | Loss: 0.3739
# Epoch 0/0 | Batch 800/914 | Loss: 0.2307
# Epoch 0/0 | Batch 900/914 | Loss: 0.1493
# 2026-02-17 09:33:14 [ERROR] Missing context for logging metric.
# Epoch 0 finished | Loss: 0.2731 | Acc: 0.9182
# Epoch 0/0 | Batch 0/960 | Loss: 0.2971
# Epoch 0/0 | Batch 100/960 | Loss: 0.3272
# Epoch 0/0 | Batch 200/960 | Loss: 0.1479
# Epoch 0/0 | Batch 300/960 | Loss: 0.6775
# Epoch 0/0 | Batch 400/960 | Loss: 0.1212
# Epoch 0/0 | Batch 500/960 | Loss: 0.1438
# Epoch 0/0 | Batch 600/960 | Loss: 0.2781
# Epoch 0/0 | Batch 700/960 | Loss: 0.2515
# Epoch 0/0 | Batch 800/960 | Loss: 0.0873
# Epoch 0/0 | Batch 900/960 | Loss: 0.2012
# 2026-02-17 09:33:19 [ERROR] Missing context for logging metric.
# Epoch 0 finished | Loss: 0.2307 | Acc: 0.9307
# Client 0 has drift 0.9989728331565857
# Client 1 has drift 0.9988750219345093
# Epoch 0/0 | Batch 0/914 | Loss: 0.1863
# Epoch 0/0 | Batch 100/914 | Loss: 0.2082
# Epoch 0/0 | Batch 200/914 | Loss: 0.3046
# Epoch 0/0 | Batch 300/914 | Loss: 0.2212
# Epoch 0/0 | Batch 400/914 | Loss: 0.1147
# Epoch 0/0 | Batch 500/914 | Loss: 0.4073
# Epoch 0/0 | Batch 600/914 | Loss: 0.2337
# Epoch 0/0 | Batch 700/914 | Loss: 0.2538
# Epoch 0/0 | Batch 800/914 | Loss: 0.2726
# Epoch 0/0 | Batch 900/914 | Loss: 0.2509
# 2026-02-17 09:33:26 [ERROR] Missing context for logging metric.
# Epoch 0 finished | Loss: 0.2610 | Acc: 0.9242
# Epoch 0/0 | Batch 0/960 | Loss: 0.2053
# Epoch 0/0 | Batch 100/960 | Loss: 0.3851
# Epoch 0/0 | Batch 200/960 | Loss: 0.1245
# Epoch 0/0 | Batch 300/960 | Loss: 0.4633
# Epoch 0/0 | Batch 400/960 | Loss: 0.2114
# Epoch 0/0 | Batch 500/960 | Loss: 0.1743
# Epoch 0/0 | Batch 600/960 | Loss: 0.2501
# Epoch 0/0 | Batch 700/960 | Loss: 0.1567
# Epoch 0/0 | Batch 800/960 | Loss: 0.0857
# Epoch 0/0 | Batch 900/960 | Loss: 0.1773
# 2026-02-17 09:33:31 [ERROR] Missing context for logging metric.
# Epoch 0 finished | Loss: 0.2149 | Acc: 0.9361
# Client 0 has drift 0.9991082549095154
# Client 1 has drift 0.9990357160568237
# Epoch 0/0 | Batch 0/914 | Loss: 0.2945
# Epoch 0/0 | Batch 100/914 | Loss: 0.1442
# Epoch 0/0 | Batch 200/914 | Loss: 0.2675
# Epoch 0/0 | Batch 300/914 | Loss: 0.2706
# Epoch 0/0 | Batch 400/914 | Loss: 0.1445
# Epoch 0/0 | Batch 500/914 | Loss: 0.3541
# Epoch 0/0 | Batch 600/914 | Loss: 0.2050
# Epoch 0/0 | Batch 700/914 | Loss: 0.1914
# Epoch 0/0 | Batch 800/914 | Loss: 0.3237
# Epoch 0/0 | Batch 900/914 | Loss: 0.0864
# 2026-02-17 09:33:36 [ERROR] Missing context for logging metric.
# Epoch 0 finished | Loss: 0.2461 | Acc: 0.9283
# Epoch 0/0 | Batch 0/960 | Loss: 0.1890
# Epoch 0/0 | Batch 100/960 | Loss: 0.3773
# Epoch 0/0 | Batch 200/960 | Loss: 0.0921
# Epoch 0/0 | Batch 300/960 | Loss: 0.4138
# Epoch 0/0 | Batch 400/960 | Loss: 0.2305
# Epoch 0/0 | Batch 500/960 | Loss: 0.1067
# Epoch 0/0 | Batch 600/960 | Loss: 0.1165
# Epoch 0/0 | Batch 700/960 | Loss: 0.0750
# Epoch 0/0 | Batch 800/960 | Loss: 0.0515
# Epoch 0/0 | Batch 900/960 | Loss: 0.2304
# 2026-02-17 09:33:41 [ERROR] Missing context for logging metric.
# Epoch 0 finished | Loss: 0.2033 | Acc: 0.9392

# %%
fig, (ax1, ax2, ax3) = plt.subplots(1,3, figsize=(16,4))
fig, (ax4, ax5, ax6) = plt.subplots(1,3, figsize=(16,4))
fix, (ax7, ax8, ax9) = plt.subplots(1,3, figsize=(16,4))

def fisher_trace(fisher_dict):
    total = 0.0
    for v in fisher_dict.values():
        total += v.sum().item()
    return total

import torch.nn.functional as F


for id in client_ids:
    ax1.plot(metrics_list[id]['training_loss'], label=f'Client {id}')
    ax2.plot(metrics_list[id]['training_accuracy'], label=f'Client {id}')
    ax3.plot(metrics_list[id]['norm'], label=f'Client {id}')

    trace = [fisher_trace(d) for d in metrics_list[id]['fisher']]
    ax4.plot(trace, label=f'Client {id}')


    g_global = torch.stack(metrics_list[id]['global_grad'], dim=1)
    g_local = torch.stack(metrics_list[id]['local_grad'], dim=1)

    norm = torch.linalg.vector_norm(g_local - g_global, dim=0)
    ax5.plot(norm, label=f'Client {id}')


    cos_sim = F.cosine_similarity(g_local, g_global, dim=0)
    ax6.plot(cos_sim, label=f'Client {id}')

    dissim = torch.norm(g_local - g_global, dim=0)**2 / (
    torch.norm(g_global, dim=0)**2 + 1e-12)
    ax7.plot(dissim, label=f'Client {id}')

    ax8.plot(metrics_list[id]['weight_cosine_sim'], label=f'Client {id}')

    ax9.plot(metrics_list[id]['feature_drift'], label=f'Client {id}')





ax1.legend()
ax1.set_title('Training loss')

ax2.legend()
ax2.set_title('Training accuracy')

ax3.legend()
ax3.set_title(r'Frobenius norm: $\|w_{local} - w_{global}\|^2$')

ax4.legend()
ax4.set_title('Fisher information trace')

ax5.legend()
ax5.set_title(r'Gradient difference $L_2$ norm $\| g_{local} - g_{global}\|^2$')

ax6.legend()
ax6.set_title('Gradient cosine similarity')

ax7.legend()
ax7.set_title(r'Gradient dissimilarity ratio: $\frac{\| g_{local} - g_{global} \|^2}{\|g_{global}\|^2} $')

ax8.legend()
ax8.set_title('Weight cosine similarity')

ax9.legend()
ax9.set_title(r'Feature drift $\|f_{local} - f_{global}\|^2$')
plt.show()

# %%
def fisher_layer_norms(fisher_dict):
    return {
        k: v.sum().item()
        for k, v in fisher_dict.items()
    }

# assume all clients share same layer names
layer_names = list(metrics_list[client_ids[0]]['fisher'][0].keys())
n_layers = len(layer_names)
n_rounds = 10

fisher_matrix = np.zeros((n_rounds, n_layers))

for d in range(n_rounds):
    layer_fisher = fisher_layer_norms(
        metrics_list[client_ids[0]]['fisher'][d]
    )
    fisher_matrix[d] = [layer_fisher[k] for k in layer_names]

import matplotlib.pyplot as plt

plt.figure(figsize=(10,6))
plt.imshow(fisher_matrix, aspect='auto')
plt.colorbar(label="Layer Fisher Trace")
plt.xticks(range(n_layers), layer_names, rotation=90)
plt.yticks(range(n_rounds), range(n_rounds))
plt.xlabel("Layer")
plt.ylabel("Round")
plt.title("Fisher Evolution Over Rounds")
plt.tight_layout()
plt.show()
